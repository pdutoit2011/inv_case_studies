# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle, resample
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, plot_confusion_matrix, roc_auc_score
from sklearn.model_selection import cross_val_score, cross_val_predict

import matplotlib.pyplot as plt

import scikitplot as skplt

import pickle

# %%
def test_languages(X_test, true_values, predictions):
    """"
    Takes in data and model predictions. Prints results to visualize performance
    """
    
    true_values = np.array(true_values)
    
    for i, sentence in enumerate(X_test):
        prediction = float(predictions[i])
        true_value = float(true_values[i])
        print("Prediction: " + str(labels[prediction]))
        print("Actual Language: " + str(labels[true_value]))
        print("Input Sentence: ")
        print(sentence)
        print('\n')

# %%
df = pd.read_csv('lang_data_processed.csv')

# %%
df.head()
# Out:
#                                 text   language
# 0   things that go bump in the night    English
# 1             keep it under your hat    English
# 2  die laaitie se hakskene word rooi  Afrikaans
# 3                            earmark    English
# 4                      bums on seats    English

# %%
# create binary labels
df['labels'] = df.language.map({'English': 0, 'Afrikaans': 1, 'Nederlands': 2})

# %%
X_train, X_test, y_train, y_test = train_test_split(df.text, df.labels, test_size = 0.33, random_state = 42)

# %%
train_df = pd.concat([y_train, X_train], axis=1, join='inner')
train_df.labels.value_counts()
# Out:
# 0    1237
# 1     374
# 2      37
# Name: labels, dtype: int64

# %%
class0 = train_df[train_df.labels == 0]
class1 = train_df[train_df.labels == 1]
class2 = train_df[train_df.labels == 2]
max = train_df.labels.value_counts().max()

if len(train_df[train_df.labels == 0]) == max:
    majority = class0
    minority1 = class1
    minority2 = class2
elif len(train_df[train_df.labels == 1]) == max:
    minority1 = class0
    majority = class1
    minority2 = class2
else:
    minority1 = class0
    minority2 = class1
    majority = class2

# %%
new_minority1 = resample(minority1, 
                   replace=True,     # sample with replacement
                   n_samples=majority.shape[0],    # to match majority class
                   random_state=42)

new_minority2 = resample(minority2, 
                   replace=True,     # sample with replacement
                   n_samples=majority.shape[0],    # to match majority class
                   random_state=42)

train_df = pd.concat([majority, new_minority1])
train_df = pd.concat([train_df, new_minority2])
train_df = shuffle(train_df, random_state=42)

train_df.labels.value_counts()
# Out:
# 1    1237
# 2    1237
# 0    1237
# Name: labels, dtype: int64

# %%
y_train = train_df.labels
X_train= train_df.text

# %%
tfidf_vect = TfidfVectorizer(analyzer='char', ngram_range=(1,3))
model = MultinomialNB()
text_clf = Pipeline([('tfidf', tfidf_vect),
                    ('clf', model),
                    ])

# %%
text_clf.fit(X_train, y_train)
predictions = text_clf.predict(X_test)
accuracy_score(y_test,predictions)
# Out:
# 0.9568965517241379

# %%
scores = cross_val_score(text_clf, df.text, df.labels, cv=5)
print(scores.mean())
# Out:
# 0.9654471544715447

# %%
print(classification_report(y_test, predictions, target_names=df.language.unique()))
# Out:
#               precision    recall  f1-score   support
#
#      English       1.00      0.96      0.98       602
#    Afrikaans       0.87      0.98      0.93       188
#   Nederlands       0.71      0.77      0.74        22
#
#     accuracy                           0.96       812
#    macro avg       0.86      0.90      0.88       812
# weighted avg       0.96      0.96      0.96       812

# %%
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
class_names = ['English', 'Afrikaans', 'Nederlands']
for title, normalize in titles_options:
    disp = plot_confusion_matrix(text_clf, X_test, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    plt.grid(False)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.grid(False)
plt.show()
# Out:
# Confusion matrix, without normalization
# [[575  22   5]
#  [  1 185   2]
#  [  0   5  17]]
# Normalized confusion matrix
# [[0.9551495  0.03654485 0.00830565]
#  [0.00531915 0.98404255 0.0106383 ]
#  [0.         0.22727273 0.77272727]]

# %%
labels = {0.0:'English', 1.0:'Afrikaans', 2.0: 'Nederlands'}
test_languages(X_test, y_test, predictions)
# Out:
# Prediction: English
# Actual Language: English
# Input Sentence:
# the chickens come home to roost
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go off halfcocked
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# designer stubble
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# high five
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bone idle
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# away with the fairies
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# going to hell in a handbasket
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# good riddance
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy maak of hy geld in die bank het
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# dock your pay
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# billy no mates
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# clean breast  make a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# all publicity is good publicity
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# shuffle off this mortal coil
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# its that man again
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# walk the walk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# primrose path
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# n ou bok hou van jong blare
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# de puntjes op de i zetten
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# mans inhumanity to man
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# chinese whispers
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# jump on the bandwagon
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pass over to the other side
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# gofaster
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# to big for your breeches
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# morning person
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# preaching to the choir
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hush puppies
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# teenspoed is deel van die lewe
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# squeaky bum time
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go over like a lead balloon
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# platsak wees
#
#
# Prediction: Afrikaans
# Actual Language: Nederlands
# Input Sentence:
# eind goed al goed
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# seen better days
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# gestewel en gespoor
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# spick and span
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# jy kan nie die armes ryk maak deur die rykes te verarm nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# smallest room in the house  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bone up on
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the cut of your jib
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# may you live in interesting times
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# foot in the door  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# to travel hopefully is a better thing than to arrive
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the pen is mightier than the sword
#
#
# Prediction: Nederlands
# Actual Language: Afrikaans
# Input Sentence:
# dis nie alle goud wat blink nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# you cant teach an old dog new tricks
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# shot heard round the world  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# geld wat sleg is maak krom wat reg is
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# two heads are better than one
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hard cases make bad law
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a daniel come to judgement
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy moet nie met sy rondloperhondmaniere hier kom kuier nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# nobrainer
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# kilroy was here
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# get underway
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# walk free
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy doen dermwerk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# just in time
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# woe betide you
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# suspension of disbelief
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ons is wat ons herhaaldelik doen perfeksie is derhalwe nie ‘n daad nie maar ‘n gewoonte
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# by dint of
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# inside out
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# baptism of fire
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go to the mattresses
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# doom and gloom
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# multitude of sins
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# as jy aas roer stink dit
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# catbird seat  in the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# behandel jou meerdere met beleefdheid omdat dit jou plig is jou gelyke omdat dit jou plesier is jou mindere omdat dit jou voorreg is die voorreg is aangenamer as die plesier en die plesier is soeter as die plig
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dis ‘n tragedie as daar iets in jou sterf terwyl jy nog lewe
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# keep at bay
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy staan of hy geld in die bank het
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pearls before swine
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the penny drops
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# oh my stars and garters
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# derringdo
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# by die verkeerde boom blaf
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# get on my wick
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# nation of shopkeepers  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# blot on the landscape
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die liefde is ‘n dubbeldoor – iets te wen en iets verloor
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# much ado about nothing
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# tussen die bye maar nog nie by die koekie nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fainthearted
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# little bird told me  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# never knowingly undersold
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# living on borrowed time
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# whats in a name that which we call a rose by any other name would smell as sweet
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# its better to give than to receive
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# as jy geluk wil vind en soek sal jy dit kry soos die ou dame haar bril – al die tyd veilig op haar neus…
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# put on the wooden overcoat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# wave a red rag to a bull
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# movers and shakers
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# high on the hog
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hobbyhorse
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# legend in ones own lifetime
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# square meal
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# life begins at forty
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# vanaand braai ons weer ‘n slag skaalvleis
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# is the pope polish
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# barking up the wrong tree
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# quick and the dead  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# senior citizen
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy laat lê nie kos nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# mea culpa
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# riley  the life of
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# chaise lounge
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# “dis jy wat met haar getjoingtjoing het en nie ek nie” – mikro gonnakolk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# raspberry tart
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# al die paaie lei na rome en die kronkelpaaie na ons drome
#
#
# Prediction: Nederlands
# Actual Language: English
# Input Sentence:
# alter ego
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# close quarters
#
#
# Prediction: Afrikaans
# Actual Language: Nederlands
# Input Sentence:
# als de kat van huis is dansen de muizen op tafel
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ps and qs  mind your
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the pip  getgothave
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die parlement is moerland toe
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# seks is soos jou salaristjek mens praat nie regtig daaroor nie want netnou kry die ander ou meer as jy
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a pig in a poke
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fiddling while rome burns
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ginned up
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ministering angel shall my sister be  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# out of sight out of mind
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# “hier het een gesit en pikstele knyp”  – ingestuur deur lödveteig nan
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# sleep tight
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# load of cobblers
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# by hook or by crook
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ask not for whom the bell tolls
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# act the giddy goat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as white as snow
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bad hair day
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ’n gedurige gedrup maak ’n gat in ’n klip
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# shambles
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bunny boiler
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# by the short hairs
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# walk the plank
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die meisies by tukkies is gek oor mieliestamp
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# lifes too short
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# lock stock and barrel
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a golden key can open any door
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the whole kit and caboodle
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bats in the belfry
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# whoopsadaisy
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# big fish in a small pond  a
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dit is net ‘n brekfis
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# teenspoed ontlont talente wat in voorspoed dormant sou bly
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# toe maar môre bak ma koekies
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# common sense
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# knock off
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# daar is  soorte werksmense een werk vir sy loon – die ander word beloon vir sy werk
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dieselfde water draai die verstandige man se meule wat die dwaas se grond verspoel
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# trou die dogter van ‘n goeie ma
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# abracadabra
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# big wig
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# urban myth
#
#
# Prediction: Nederlands
# Actual Language: English
# Input Sentence:
# all in all
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# red letter day
#
#
# Prediction: Afrikaans
# Actual Language: Nederlands
# Input Sentence:
# geen woorden maar daden
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bane of your life
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# sexton blake
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cant hold a candle to
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy probeer hoër vlieg as wat sy vlerke lank is
#
#
# Prediction: Afrikaans
# Actual Language: Nederlands
# Input Sentence:
# iets is beter dan niets
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# topsyturvy
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bite the bullet
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sukses is die kuns om hooi te maak van die gras wat ander mense onder hul voete vertrap
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# vele handen maken licht werk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# down in the dumps
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# wanneer die moeilikheid so groot soos ‘n berg is klim die wyse booor die dwaas graaf ‘n tonnel onderdeur en bly binne vassteek die lafaard draai om
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# de stoute schoenen aantrekken
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sy vertel hom waar die bus stop
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cook the books
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# touch wood
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tattoo phrases and sayings
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# wanneer jy dink dat jy onmisbaar is moet jy ‘n emmer water neem jou vuis en arm daarin druk en dan stadig uittrek die gat wat in die water oorbly is die mate waarin jy gemis sal word
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# think outside the box
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# market forces
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# zwijgen is goud
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# knight in shining armour
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# rub of the green
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# keep your hands clean
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ball and chain
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# haar haan moet altyd koning kraai
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# shot in the arm
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the  unkindest cut of all
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# four by two
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in the sticks
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# beer and skittles
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# life of riley
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as cold as any stone
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# been there done that
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as happy as
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cast the first stone
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# road rage
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# using a sledgehammer to crack a nut
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go and boil your head
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sak sarel pa wil n springbok skiet op dooierus
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# yellow peril
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a red rag to a bull
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tout de suite
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# son of a gun
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# brandewyn raas as dit uit die vat uit kom
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# turn up trumps
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# out of sorts
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# thats all she wrote
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# blown to smithereens
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# below the salt
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the buck stops here
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# red rag to a bull  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# nip in the bud
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# chalk and cheese
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pork pies
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the real mccoy
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# daar is lewe in die grond dit gaan in die saad in en wanneer dit versteur word gaan dit ook in die man wat dit versteur
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as snug as a bug in a rug
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fast and loose
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy is ganspen
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# so blind soos n mol
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# friends romans countrymen lend me your ears
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# trick or treat
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# jou akker sal kraak
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# vir dertig stukke silwer
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go to the dogs
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# heavens to murgatroyd
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ’n warm hart steek die ander aan die brand
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# driving while black
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy’t sommer so sjierts by ons verbygejaag
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pull up stakes
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# big apple  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# short shrift
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# om groot te skrik is soms meer werd as goeie raad
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# someone is walking over my grave
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# gloom and doom
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# not for all the tea in china
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# paper tiger
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the call of the wild
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# little knowledge is a dangerous thing  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# spring forward fall back
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die taal van die veroweraar in die mond van die verowerde is die taal van slawe
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# staan of hy geld in die bank het
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ek sal jou opkoffie as jy sê my span speel sleg
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# touchyfeely
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cold shoulder
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as happy as larry
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# your name is mud
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as busy as a bee
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# we have seen better days
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# senior burgers vraag “wat maak julle heeldag” antwoord “ons soek ons goed en probeer onthou wat ons vergeet het”
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# up the apples and pears
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die lewe is nie net swart en wit nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ek sien die veld die bosse berge vlakte ek hoor hoe fluister grasse stroom en wind o heer u sorg vir klein vir groot vir alles en u sorg dag na dag vir my u kind
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# in spades
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dis nie ‘n pyp dagga werd nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# nip and tuck
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# kind onthou net één ding jy kon nie jou ouers en voorouers kies nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# geleenthede gaan by mense verby omdat dit ‘n oorpak aan het en na werk lyk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fifth column
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# chop and change
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# daai klas wyn is nie vir ‘n man met ‘n dun kopvel nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# as die hemel val is ons almal dood
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fool and his money are soon parted  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# make a clean breast of it
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# soort zoekt soort
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# gooi weg die blink horlosies – werk van sonop tot sononder en die plaas is jou baas – nie jy nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy was kleindag so onbeskof
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# nod  the land of
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# piping hot
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the elephant in the room
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fair and square
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# dont change horses in midstream
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# onder die besemstok staan
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# grandfather clock
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# je moet het ijzer smeden als het heet is
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as xxx as yyy
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cost an arm and a leg
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the ends of the earth
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# almanakke druk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the quick and the dead
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# elke mens kom vroeër of later sy waterloo teë
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# like it or lump it
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# do unto others as you would have them do to you
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# take with a grain of salt
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# not a dickybird
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# silence is golden
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# waar een wil is is een weg
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# my husband and i
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dié naweek drink ons tot die bodem
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# give no quarter
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as cool as a cucumber
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# proof of the pudding is in the eating  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# wat laat oom japie weer die grootsê so hoog uit die takke haal
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dit het gister net so ‘n slangsleepseltjie gereent in die kaap
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# crapper  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# mums the word
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# high wide and handsome
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# down the tubes
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# buckle down
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# upper crust
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n man kan nog per ongeluk op jou tone trap maar as hy op jou kop trap is dit moedswillig
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# you get on my wick
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# beyond our ken
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# gry  words ending in
#
#
# Prediction: Afrikaans
# Actual Language: Nederlands
# Input Sentence:
# de laatste druppel doet de emmer overlopen
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# drag race
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dit is maklik gesê maar die eend lê die eier
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tongue in cheek
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# dont call us well call you
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# lifes not all beer and skittles
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# steal my thunder
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# silly billy
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# luiaard gaan na die mier
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# dead cat bounce
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as the crow flies
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# king james version of the bible
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# abide with me
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy vryf graag haar boud
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# koerland se vleiseter is n lui kalant en so uitgeslape soos my prokureur nie kan droom om te wees
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pigs might fly
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# at ones beck and call
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as straight as a die
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# back to the drawing board
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# youve never had it so good
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# homonyms
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# brownie points
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hoe beter man jy is hoe jammerder is dit van die fout wat jy het dis op die wit papier wat die swart klad duidelik wys
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# action man
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die moeilikste besluite in die lewe is om te besluit watter brûe om oor te steek en watter om te verbrand
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# push the envelope
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# worth ones salt
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ones hearts content
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# between you me and the bedpost
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# wees dankbaar as jou kinders dik snye brood vra – meel is goedkoper as medisyne
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the great unwashed
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# april fool
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# stitch in time saves nine  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hell or high water
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ek is in die dolliwarie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# jy kan nie met skoon hande modder gooi nie nog minder met ‘n rein mond gif spoeg
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# verbosity leads to unclear inarticulate things
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hung drawn and quartered
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# aid and abet
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# now is the winter of our discontent
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# all agog
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# spitting feathers
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# kick your heels
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# eye of newt and toe of frog wool of bat and tongue of dog
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tickled pink
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# quid pro quo
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# balance of trade  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# op iemand se dak afklim
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# carbon footprint
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# speak of the devil
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cats cradle
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# white elephant
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# stars and garters  my
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as good luck would have it
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the love that dare not speak its name
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# dollars to donuts
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# all at sea
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# on the warpath
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# met ‘n aalwynpil in jou kies loop
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the apple of my eye
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# thou shalt not kill
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as easy as pie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go to the foot of our stairs
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# not worth a plugged nickel
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the living daylights
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# no dice
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# al fresco
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# silly season
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# sleep on a clothesline
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# swan song
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# mind your ps and qs
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# has the cat got your tongue
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ek verwonder my dat daardie sterk vrou so skielik dood is en daardie siek man so lank leef…
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# agter die donkerste onweerswolke is die ewige son nog altyd daar
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in like flynn
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dit sal my laat ystervarke vang
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# flogging a dead horse
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# wag tot letjie kom
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# shot in the dark
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# surfing the netsurfing the internetsurfing the web
#
#
# Prediction: Nederlands
# Actual Language: English
# Input Sentence:
# bad egg
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# selfs in my oupagrootjie se tyd was daar iets wat jou aan die slaap kon kry hulle het dit werk genoem…
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# mad as a hatter
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the life of riley
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# veel geskreeu en weinig wol
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# broad in the beam
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the die has been cast
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hou jy van hospitaalkos  bydrae herman janse van rensburg
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# absolute power corrupts absolutely
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a sorry sight
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# curiosity killed the cat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# true blue
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# jy sal verbaas wees hoeveel van jou geheime sondes jou bure weet hoekom sal hulle met jou daaroor praat hulle reken jy weet dit immers self
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# daar is net ‘n trekseltjie koffie oor in die pot
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pipe down
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# jy kan van ‘n padda nie vere pluk nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# donkie vasmaak
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# giddy goat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# handle with kid gloves
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die goed wat jy aan jou ouer doen dit belê jy rente op rente maar wat jy aan jou kind doen dit is jy die meeste van die tye met kapitaal en rente kwyt dis ‘n gelukkie as jy daar iets van terugkry moet niet daarop reken
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# foot of our stairs  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# up to snuff
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# so besig soos n miernes wees
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# white as snow
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# jy steek jou kop in n bynes
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# third degree  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die mooiweer sal jou nie beskadig omdat jy jou jas en sambreel verniet saamgeneem het nie
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# alle begin is moeilijk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# have a captain cook
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# men in suits
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# om vas te staan wanneer jy iets weet en toe te gee dat jy soms iets nie weet nie dit is kennis
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# busy as a bee
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# through thick and thin
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# come clean
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# blow a raspberry  see raspberry tart
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# je moet de vieze was niet buiten hangen
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# salt of the earth  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as happy as a clam
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# jack the lad
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# comparisons are odious
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# darby and joan
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fait accompli
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# iemand afpoeier
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# diamond in the rough
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# i told you is was ill
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# neither fish nor flesh nor good red herring
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# on the qt
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# words ending in gry
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# my old dutch
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# forewarned is forearmed
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# havent got a clue
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go like the clappers
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# call a spade a spade
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# petty cash
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# wie het laatst lacht lacht het best
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# needs must
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# wax lyrical
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# economical with the truth
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tawdry
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# three sheets to the wind
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# under the thumb
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dit is te dik vir ‘n daalder
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# freezing temperatures
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sy gesang is uit
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# throw in the towel
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die plaas is nie ‘n koei wat in die hemel kos kry en op aard gemelk kan word nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# skid row
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# so bang soos ‘n haas vir ‘n hond
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bill stickers is innocent
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# as jy by iemand se vuur gaan sit moet jy eers kyk van watter kant die wind waai
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dawid jones sê hulle melk ons nou sô vir die armes asof dit ons skuld is dat hul arm is
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# thumbs up
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# good samaritan
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# raining cats and dogs
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# so tuis wees soos n vis in die water
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# je moet niet op één paard wedden
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy hou van op die lawaaiwa klim
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# like being savaged by a dead sheep
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fobbed off
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the bane of my life
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# mouthwatering
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tower of strength
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n sinikus is iemand wat die prys van alles weet en die waarde van niks
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# show a leg  see shake a leg
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# mutts nuts  the
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# oopsadaisy
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# extraordinary rendition
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# daar is geen sukkel by kuns nie en geen kuns by sukkel nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# stones throw
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# channel surfing
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# test your mettle  see show your mettle
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a rose is a rose is a rose
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fall guy
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# by gum
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# good men and true
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# liefde maakt blind
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# bitter in die mond maak die hart gesond
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# geen nieuws goed nieuws
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# born within the sound of bow bells
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# in die gras byt
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# big cheese  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die kwaaikind moet uitgebrand word
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# merry christmas
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# selfs in die slegste vorm van werk raak die mens se hele siel in harmonie did oomblik dat dit begin werk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cherchez la femme
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# keep your chin up
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sy is ‘n regte ou tierwyfie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bugger bognor
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# genade het nie ‘n horing nie dalk beter bekend as “genade het nie horings nie” 🙂
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# langnekkaatjie soen
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pull the wool over your eyes
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# piggyback
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# born again
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# waar bloed nie kan kruip nie loop dit
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# whole shebang  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# usual suspects  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# charley horse
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the best laid schemes of mice and men
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# jacob is doringskof vir julius
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# jors se opsykind is al pramhoog  pramhoog – hoe vrouens in namakwaland hoogte aandui
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# wooden hill to bedfordshire
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# devil and the deep blue sea
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# about turn
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# dont die like i did
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a fish rots from the head down
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# is this a dagger which i see before me
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fits to a tee
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# balance of power  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# armoede leer ‘n maer hond bene kou
#
#
# Prediction: Afrikaans
# ...
# Input Sentence:
# jou karakter soos die fondamente van ‘n huis is onder die oppervlakte
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy kollekteer al weer by haar
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in the club
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy loop aandklas
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# loose cannon
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die beste een vinnigste manier om ander mens te waarder is om te probeer om hulle werk te doen
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# similes
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# brass tacks  get down to
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n blaadjie uit iemand se boek neem
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# knickknack
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the darkest hour is just before the dawn
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dit gaan maar patats
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# woman needs a man like a fish needs a bicycle  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# play silly buggers
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# paying guest  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the powers that be
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# what are you like
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die berg het ‘n muis gebaar
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# theres an r in the month
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# gou met die pen
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# blast from the past  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# an eye for an eye a tooth for a tooth
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# misery acquaints a man with strange bedfellows
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# what part of no dont you understand
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ill be there with bells on
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# press into service
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# shake a leg
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# survival of the fittest
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# halfcocked
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# my minds eye
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# jack  phrases that include the name jack
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# to a t
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# moenie jou kinders onskuldige plesier belet nie hulle sal dit steel en dan is jy nie daarby om te sien dat hulle nie die skuldige by steel nie
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# apple pie order
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# not my cup of tea
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# thinking cap
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# full tilt
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cut of your jib  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# famous last words the ironic phrase
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# copperbottomed
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# level playing field
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# better late than never
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cocksure
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# safe pair of hands  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# something for the weekend sir
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# wrong end of the stick  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cute as a bugs ear
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bottomup
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# onehit wonder
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in a trice
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# moenie roem dat jy geen kwaad gedoen het nie watter goed het jy gedoen” ‘n steeks perd is nie meer werd as een wat skop nie hy beteken minder – een wat skop kan jy terug skop maar jy kan nie terug steeks wees nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# morbid obesity
#
#
# Prediction: English
# Actual Language: Afrikaans
# Input Sentence:
# sy doen die canyon tango
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n gebraaide hoender vlieg niemand in die mond nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# prick up your ears
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# carpe diem
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# gridlock
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# swart grietjie soen
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die beeste het in die brand geloop
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# know the ropes
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# game of two halves
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# if i had my druthers
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tit for tat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# talk through ones hat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# grist to the mill
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tail wagging the dog  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# paint the town red
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# davy jones locker
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a foregone conclusion
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the ants are my friends theyre blowing in the wind
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pigs ear
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# maak die pas van die natuur jou eie – haar geheim is geduld en volharding
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy het ‘n hallelujagesig en jazzvoete
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# chow down
#
#
# Prediction: Nederlands
# Actual Language: English
# Input Sentence:
# egg on
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# children should be seen and not heard
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# quality time
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# rob peter to pay paul
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# beat around the bush
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# left hand doesnt know what the right hand is doing
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hell in a handbasket
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n mens kan met ‘n bokwa en ‘n lang span osse daarin draai
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# no room to swing a cat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# give a wide berth
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a friend in need is a friend indeed
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# living off the fat of the land
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sou daar ‘n weersien wees of is ons verdoem tot verpulwerde deeltjies van eens warm vlees
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in the cart
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# laid out in lavender
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy is so los soos ‘n druiwetros
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# man after my own heart  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# have an axe to grind
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# okeydokey
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# lo and behold
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# brummagem screwdriver
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# stuff and nonsense
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# bokveld toe gaan
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# blow your mind
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# he who can does he who cannot teaches
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the salt of the earth
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# straight as a die
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# heavens to betsy
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy het ‘n aap op sy rug
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy groei deur sy hare
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# dickybird  not a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# you cant get blood out of a stone
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# toodleoo
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# waar aas is vergader die arende
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# coin a phrase
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fathom out
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# when the shit hits the fan
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die pad is snuif tussen soebatsfontein en koingnaas
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the exception which proves the rule
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# peter out
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# neer do well
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# daai jors kan vir jou lank ploeg
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# spill the beans
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# how do you do
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# much of a muchness
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# beggars cant be choosers
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# frog in the throat  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# baby boomer
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# get  underway
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# innocent until proven guilty
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# leadpipe cinch
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# mud  your name is
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# heads up
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# to sleep perchance to dream ay theres the rub
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the back of beyond
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# many a true word is spoken in jest
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# on the ball
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ship shape and bristol fashion
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# stinking rich
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# jetblack
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# met geweld kan mens jou duim in jou hol afbreek
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a stitch in time saves nine
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# load of codswallop
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# writing is on the wall  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# i see you stand like greyhounds in the slips
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# lose your marbles
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# not playing with a full deck
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ace in the hole
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tits up
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# wing it
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# sods law
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as good as gold
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# rome is nie in een dag gebou nie so gaan jou gang rustig  hoe meer haas hoe minder spoed
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# blood sweat and tears
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# all you can eat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# filthy rich
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the heebiejeebies
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# some men are born mediocre some men achieve mediocrity and some men have mediocrity thrust upon them
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# elke hart het sy smart
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a nest of vipers
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# woe is me
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# worse for wear
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# piet pompies van soetmelksvlei is nie van hier nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# exceedingly well read
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# another think coming
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tempest in a teapot
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# rack your brains
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy raak toe sommer doringbos vir haar
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# riding shotgun
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# o romeo romeo wherefore art thou romeo
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# left in the lurch
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# kerm soos ‘n kat oor ‘n derm
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# “hy is twee castles kort van ‘n sixpack”  – ingestuur deur andre
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# let not poor nelly starve
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# bid vir ‘n goeie oes maar hou aan werk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in the twinkling of an eye
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# religion is the opium of the people
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# young turk
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# erken as jy verkeerd is en bly stil as jy reg is
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# my cup runneth over
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# like two peas in a pod

# %%
from sklearn.metrics import roc_auc_score

y_prob = text_clf.predict_proba(X_test)

macro_roc_auc_ovo = roc_auc_score(y_test, y_prob, multi_class="ovo",
                                  average="macro")
weighted_roc_auc_ovo = roc_auc_score(y_test, y_prob, multi_class="ovo",
                                     average="weighted")
macro_roc_auc_ovr = roc_auc_score(y_test, y_prob, multi_class="ovr",
                                  average="macro")
weighted_roc_auc_ovr = roc_auc_score(y_test, y_prob, multi_class="ovr",
                                     average="weighted")
print("One-vs-One ROC AUC scores:\n{:.6f} (macro),\n{:.6f} "
      "(weighted by prevalence)"
      .format(macro_roc_auc_ovo, weighted_roc_auc_ovo))
print("One-vs-Rest ROC AUC scores:\n{:.6f} (macro),\n{:.6f} "
      "(weighted by prevalence)"
      .format(macro_roc_auc_ovr, weighted_roc_auc_ovr))
# Out:
# One-vs-One ROC AUC scores:
# 0.995356 (macro),
# 0.996468 (weighted by prevalence)
# One-vs-Rest ROC AUC scores:
# 0.996512 (macro),
# 0.998261 (weighted by prevalence)

# %%
y_prob = text_clf.predict_proba(X_test)

plot = skplt.metrics.plot_roc(y_test, y_prob)
plt.title("ROC Curves");

# %%
train_df = pd.concat([df.labels, df.text], axis=1, join='inner')
train_df.labels.value_counts()
# Out:
# 0    1839
# 1     562
# 2      59
# Name: labels, dtype: int64

# %%
class0 = train_df[train_df.labels == 0]
class1 = train_df[train_df.labels == 1]
class2 = train_df[train_df.labels == 2]
max = train_df.labels.value_counts().max()

if len(train_df[train_df.labels == 0]) == max:
    majority = class0
    minority1 = class1
    minority2 = class2
elif len(train_df[train_df.labels == 1]) == max:
    minority1 = class0
    majority = class1
    minority2 = class2
else:
    minority1 = class0
    minority2 = class1
    majority = class2

# %%
new_minority1 = resample(minority1, 
                   replace=True,     # sample with replacement
                   n_samples=majority.shape[0],    # to match majority class
                   random_state=42)

new_minority2 = resample(minority2, 
                   replace=True,     # sample with replacement
                   n_samples=majority.shape[0],    # to match majority class
                   random_state=42)

train_df = pd.concat([majority, new_minority1])
train_df = pd.concat([train_df, new_minority2])
train_df = shuffle(train_df, random_state=42)

train_df.labels.value_counts()
# Out:
# 2    1839
# 1    1839
# 0    1839
# Name: labels, dtype: int64

# %%
from sklearn.model_selection import cross_val_predict

y_train_pred = cross_val_predict(text_clf, train_df.text, train_df.labels, cv=3)

# %%
print(classification_report(train_df.labels, y_train_pred, target_names=df.language.unique()))
# Out:
#               precision    recall  f1-score   support
#
#      English       1.00      0.96      0.98      1839
#    Afrikaans       0.97      0.99      0.98      1839
#   Nederlands       0.98      1.00      0.99      1839
#
#     accuracy                           0.98      5517
#    macro avg       0.98      0.98      0.98      5517
# weighted avg       0.98      0.98      0.98      5517

# %%
confusion_matrix(train_df.labels, y_train_pred)
# Out:
# array([[1760,   56,   23],
#        [   2, 1828,    9],
#        [   0,    0, 1839]], dtype=int64)

# %%
text_clf.fit(train_df.text, train_df.labels)
# Out:
# Pipeline(memory=None,
#          steps=[('tfidf',
#                  TfidfVectorizer(analyzer='char', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 3), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, use_idf=True,
#                                  vocabulary=None)),
#                 ('clf',
#                  MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))],
#          verbose=False)

# %%
pickle.dump(text_clf, open('language_classifier', 'wb'))
