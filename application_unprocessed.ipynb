# %%
import pandas as pd

import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle, resample
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, plot_confusion_matrix, roc_auc_score
from sklearn.model_selection import cross_val_score

import matplotlib.pyplot as plt

import scikitplot as skplt

import pickle

import re

import string

# %%
def test_languages(X_test, true_values, predictions):
    """"
    Takes in data and model predictions. Prints results to visualize performance
    """
    
    true_values = np.array(true_values)
    
    for i, sentence in enumerate(X_test):
        prediction = float(predictions[i])
        true_value = float(true_values[i])
        print("Prediction: " + str(labels[prediction]))
        print("Actual Language: " + str(labels[true_value]))
        print("Input Sentence: ")
        print(sentence)
        print('\n')

# %%
def text_process(mess):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Change to lower case
    3. Remove numbers
    4. Remove white space
    5. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in mess if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Convert upper to lower case
    nopunc = nopunc.lower()
    
    # Remove numbers
    nopunc = re.sub(r'\d+', '', nopunc)
    
    # Remove white spaces
    return nopunc.strip()

# %%
def read_data(filename):
    
    df = pd.read_csv(filename)    
    return df

# %%
def process_data(filename):
    
    df = read_data(filename)
    df.dropna(inplace=True)
    df.drop_duplicates(inplace=True)
    df['text'] = df['text'].astype(str)
    df['text'] = df['text'].apply(text_process)
    df.drop_duplicates(inplace=True)
    df['labels'] = df.language.map({'English': 0, 'Afrikaans': 1, 'Nederlands': 2})
    
    return df

# %%
df = process_data('lang_data_holdout_unprocessed.csv')

# %%
text_clf = pickle.load(open('language_classifier', 'rb'))

# %%
predict_final = text_clf.predict(df.text)
print(classification_report(df.labels, predict_final, target_names=df.language.unique()))
# Out:
#               precision    recall  f1-score   support
#
#      English       1.00      0.97      0.99       199
#    Afrikaans       0.97      1.00      0.99        70
#   Nederlands       0.57      1.00      0.73         4
#
#     accuracy                           0.98       273
#    macro avg       0.85      0.99      0.90       273
# weighted avg       0.99      0.98      0.98       273

# %%
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
class_names = ['English', 'Afrikaans', 'Nederlands']
for title, normalize in titles_options:
    disp = plot_confusion_matrix(text_clf, df.text, df.labels,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    plt.grid(False)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.grid(False)
plt.show()
# Out:
# Confusion matrix, without normalization
# [[194   2   3]
#  [  0  70   0]
#  [  0   0   4]]
# Normalized confusion matrix
# [[0.97487437 0.01005025 0.01507538]
#  [0.         1.         0.        ]
#  [0.         0.         1.        ]]

# %%
y_prob = text_clf.predict_proba(df.text)

plot = skplt.metrics.plot_roc(df.labels, y_prob)
plt.title("ROC Curves");

# %%
labels = {0.0:'English', 1.0:'Afrikaans', 2.0: 'Nederlands'}
test_languages(df.text, df.labels, predict_final)
# Out:
# Prediction: English
# Actual Language: English
# Input Sentence:
# out of sorts
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# up a gum tree
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# stand and deliver
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# al die suksesse in die wêreld is gebaseer op toewyding en ‘n goeie wil
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bring home the bacon
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# never knowingly undersold
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# jy beny my blink skoene omdat jy nie weet van die liddorings wat binne pyn nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# body surfing
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a picture is worth a thousand words
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pour oil on troubled waters
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# valentines day poems and sayings
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# aid and abet
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the pen is mightier than the sword
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# once in a blue moon
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# game is afoot  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dis nie welvaart en swier wat geluk bring nie maar kalmte en werk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# to beggar belief
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# trip the light fantastic
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a at lloyds
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the hairy eyeball
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# behandel die vreemdeling goed maar wees versigtig om hom die kans te gee om jou te behandel
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hell in a handbasket
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sien jou in ‘n dik ruk
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# julle kan dink en praat soos julle voel en oortuig is ek sal dit respekteer maar moenie die houding van aagg watt aankweek nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# murphys law
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# what part of no dont you understand
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# touch and go
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# spin jy jou driewiel
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# booby trap
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# born within the sound of bow bells
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# so bang soos ‘n bok vir ‘n skoot hael
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# heavens to betsy
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# dont throw the baby out with the bathwater
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# make your hair stand on end
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy gaan met aasdieromslagtigheid te werk
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n gebraaide hoender vlieg niemand in die mond nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# crackpot
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# waar aas is vergader die arende
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die spul daar op bergplaas sit dassie daar word nie geploeg nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# off with his head
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# giddy aunt
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hedge your bets
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# waar jy nie self by is nie word jou gesig nie gewas nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# daar is  soorte werksmense een werk vir sy loon – die ander word beloon vir sy werk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# behind every great man theres a great woman
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# rome is nie in een dag gebou nie so gaan jou gang rustig  hoe meer haas hoe minder spoed
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sy bont varkie is weg
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# great minds think alike
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# down in the dumps
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die boog kan nie altyd gespan wees nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die verhouding tussen hoofman en werknemeres is soos dié tussen die wind en die gras die gras moet buig as die wind daaroor waai
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# all at sea
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# bokwagter word
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pointblank
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the darkest hour is just before the dawn
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ontwyk die uitvraer want hy is ook ‘n verklapper
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bird in the hand is worth two in the bush  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# life begins at forty
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# dont try to teach your grandma to suck eggs
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# an ill wind
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# so arm soos ‘n kerkmuis
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# daai jors kan vir jou lank ploeg
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# forbidden fruit
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# moenie jou pêrels voor die swyne werp nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# lardydardy
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dit is nooit my eie dood waaroor ek spekuleer nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# keep it under your hat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# christmas card verses
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# like the dickens
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# neither fish nor flesh nor good red herring
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# if music be the food of love play on
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die beste een vinnigste manier om ander mens te waarder is om te probeer om hulle werk te doen
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# taken aback
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# blood sweat and tears
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go out on a limb
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# nod  the land of
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# toast of the town
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# beat around the bush
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hard man is good to find  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the devil take the hindmost
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die swaarste ding om te dra is ‘n wrok
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# let or hindrance
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n aap op jou rug hê
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# never look a gift horse in the mouth
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# sound bite
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ring a ring oroses a pocketful of posies atishoo atishoo all fall down
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as brown as a berry
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy lyk soos sondagkos
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# what god has joined together let no man put asunder
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# middle for diddle
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# black as newgates knocker
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# living on borrowed time
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# daar is net ‘n trekseltjie koffie oor in die pot
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# for crying out loud
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the ends of the earth
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# dont call us well call you
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# lark about
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# turn up trumps
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# riley  the life of
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# has the cat got your tongue
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# on the qt
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as mad as a march hare
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pipe down
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# eat my hat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# lose face
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# have an axe to grind
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# i told you is was ill
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# you get on my wick
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die beeste het in die brand geloop
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# jors is hier weg met die aanslag van die dag
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# blind leading the blind  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dieselfde water draai die verstandige man se meule wat die dwaas se grond verspoel
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# weakest link  a chain is only as strong as its
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy laat lê nie kos nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# double cross
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# gloom and doom
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# make hay while the sun shines
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# wanneer ‘n man en vrou hul huwelik begin bespreek lê hulle getuienis af by ‘n geregtelike ondersoek
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# down at heel
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# vorsprung durch technik
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# put a damper on
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pass over to the other side
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# clue  dont have a
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# weewee
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die halter afhaal
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# shillyshally
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# i spy with my little eye
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# up the pole
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# paddle your own canoe
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# gordon bennett
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# iemand dwarsdeur kyk
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# geleentheid maak die dief
#
#
# Prediction: Nederlands
# Actual Language: English
# Input Sentence:
# zigzag
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# by your leave
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fingers and thumbs
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# nest of vipers  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# stinking rich
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# you look as if youve been dragged through a hedge backwards
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# good measure  for
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bite the dust
#
#
# Prediction: Nederlands
# Actual Language: English
# Input Sentence:
# beggar belief
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# big wig
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# lala land
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# like a chicken with its head cut off
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ek gaan bietjie by haar afsaal
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go postal
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# high and mighty
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die geheim om te verveel is om alles te vertel
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# “help vir henna en troos vir koos”
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the pot calling the kettle black
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hot on the heels
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# teenspoed is deel van die lewe
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# upsadaisy
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# prime time
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# wees dankbaar as jou kinders dik snye brood vra – meel is goedkoper as medisyne
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ps and qs  mind your
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# indian giver
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# tussen die bye maar nog nie by die koekie nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# mend fences
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die sweep swiep deur die lug
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the triumph of hope over experience
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# big easy  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# kneejerk reaction
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# iemand afpoeier
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# might and main
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# huggermugger
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cheap at half the price
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a pig in a poke
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a priori
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# driving while black
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# rough diamond
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# sir walter scott phrases coined by
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# it aint over till the fat lady sings
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# best bib and tucker
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# moenie al jou geld op een perd sit nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# your money or your life
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the powers that be
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ’n dronk man val nie ver van die bar nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# power dressing
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# laat ek vir jou vertel wat vis innie kaap kos
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# lifes too short
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# toe ek begin werk het wou ek ‘n groot klomp geld gou maak later wou ek’n groot klomp geld maak terwyl ek dit geniet maar later sien ek wat jy werklik wil hê is om ‘n klein verskil te maak as jy dit kan doen kom ander dinge vanself en kan jy dit terdeë geniet
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# no truck with
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# codswallop  a load of
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# toe maar môre bak ma koekies
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a diamond in the rough
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# rabbit and pork
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# kleine potjes hebben grote oren
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# whole kit and caboodle  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# beyond belief
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# square meal
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# een hoofd vol kreuken – een geweten sonder rimpel
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the exception which proves the rule
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# gooi weg die blink horlosies – werk van sonop tot sononder en die plaas is jou baas – nie jy nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# bitter in die mond maak die hart gesond
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sy is so klein sy verdwaal in ‘n telefoonhokkie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# under the thumb
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# johann nell “dit is baie beter om te huil in ‘n luukse bmw as op ‘n tweewielfiets en dit is nog beter om jou trane te laat val van ‘n drieverdieping mansion as wat dit op jou kaia se grondvloer val”
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# swing for you
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cute as a bugs ear
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# champ at the bit
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# friday afternoon car
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# godfrey daniel
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# vir jou het ek sien aankom
#
#
# Prediction: Nederlands
# Actual Language: English
# Input Sentence:
# mal de mer
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# arende vang nie vlieë nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# skin and blister
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# theres no such thing as bad publicity
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# piss and vinegar  full of
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sy is so vet as sy by die trein uitklim kan almal asem haal
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the blind leading the blind
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fifth column
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# schijn bedriegt
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in the catbird seat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# how sharper than a serpents tooth it is to have a thankless child
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# as jy aas roer stink dit
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cold turkey
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dis ‘n goeie boeregewoonte ‘n mens kom nooit met leë hande by iemand aan nie…en jy stuur hom ook nie met leë hande weg nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hard and fast
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# silver bullet
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tanstaafl  theres no such thing as a free lunch
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# happy as a sandboy
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die geel baadjie aan hê
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# to the nth degree
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# talk through ones hat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fobbed off
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# agter geld soos die duiwel agter ‘n siel aan
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die berg het n muis gebaar
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bet your bottom dollar
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# you are what you eat
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pellmell
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the whole kit and caboodle
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# begeer nie om ‘n man van belang te wees nie maar ‘n man van waarde
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# iets is beter dan niets
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# walk the plank
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# foot in the door  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a turn up for the books
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# okeydokey
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in your face
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dit kos ‘n plaas se geld
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# rank and file
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# stonyhearted
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# designer stubble
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fool and his money are soon parted  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pull out all the stops
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bottomup
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# rise and shine
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as different as chalk and cheese
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pony up
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# praying at the porcelain altar
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# get thee behind me satan
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# wat regtig saak maak is wat jy leer terwyl jy reeds alles weet
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# duvet day
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bury your head in the sand
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hit the nail on the head
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# vergelyk eers wat jy het met wat jy nie het nie – dan kan jy waardeer wat jy nie het nie en liefkry wat jy het
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a feather in ones cap
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# delusions of grandeur
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# devil to pay  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# wat is die belangrikste – geluk of sukses
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# waar rook is is vuur
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# if it aint broke dont fix it
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# for keeps
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# golden key can open any door  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# knock back
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tit for tat
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die boer se voetspore is die beste misstof op die land
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# swing the lead
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# daar’s ‘n geurtjie aan
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# mens evil manners live in brass their virtues we write in water
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# gofaster
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# red tape
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in a pickle
