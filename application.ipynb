# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle, resample
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, plot_confusion_matrix, roc_auc_score
from sklearn.model_selection import cross_val_score

import matplotlib.pyplot as plt

import scikitplot as skplt

import pickle

# %%
def test_languages(X_test, true_values, predictions):
    """"
    Takes in data and model predictions. Prints results to visualize performance
    """
    
    true_values = np.array(true_values)
    
    for i, sentence in enumerate(X_test):
        prediction = float(predictions[i])
        true_value = float(true_values[i])
        print("Prediction: " + str(labels[prediction]))
        print("Actual Language: " + str(labels[true_value]))
        print("Input Sentence: ")
        print(sentence)
        print('\n')

# %%
def text_process(mess):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Change to lower case
    3. Remove numbers
    4. Remove white space
    5. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in mess if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Convert upper to lower case
    nopunc = nopunc.lower()
    
    # Remove numbers
    nopunc = re.sub(r'\d+', '', nopunc)
    
    # Remove white spaces
    return nopunc.strip()

# %%
def read_data(filename):
    df = pd.read_csv(filename)
    df['labels'] = df.language.map({'English': 0, 'Afrikaans': 1, 'Nederlands': 2})
    return df

# %%
df = read_data('lang_data_holdout_processed.csv')

# %%
text_clf = pickle.load(open('language_classifier', 'rb'))

# %%
predict_final = text_clf.predict(df.text)
print(classification_report(df.labels, predict_final, target_names=df.language.unique()))
# Out:
#               precision    recall  f1-score   support
#
#    Afrikaans       1.00      0.95      0.98       192
#      English       0.94      0.99      0.96        73
#   Nederlands       0.62      1.00      0.76         8
#
#     accuracy                           0.96       273
#    macro avg       0.85      0.98      0.90       273
# weighted avg       0.97      0.96      0.97       273

# %%
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
class_names = ['English', 'Afrikaans', 'Nederlands']
for title, normalize in titles_options:
    disp = plot_confusion_matrix(text_clf, df.text, df.labels,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    plt.grid(False)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.grid(False)
plt.show()
# Out:
# Confusion matrix, without normalization
# [[183   5   4]
#  [  0  72   1]
#  [  0   0   8]]
# Normalized confusion matrix
# [[0.953125   0.02604167 0.02083333]
#  [0.         0.98630137 0.01369863]
#  [0.         0.         1.        ]]

# %%
y_prob = text_clf.predict_proba(df.text)

plot = skplt.metrics.plot_roc(df.labels, y_prob)
plt.title("ROC Curves");

# %%
labels = {0.0:'English', 1.0:'Afrikaans', 2.0: 'Nederlands'}
test_languages(df.text, df.labels, predict_final)
# Out:
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# reën by buurman – jy kry niks die here was sy vuil kindertjies eerste
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# moenie al jou geld op een perd sit nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a tinkers damn
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# like the dickens
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# one sandwich short of a picnic
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# if you think that you have another think coming
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# there but for the grace of god go i
#
#
# Prediction: Nederlands
# Actual Language: English
# Input Sentence:
# ménage à trois
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a word in edgeways
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# te laat vir sy eie begrafnis wees
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# jobs for the boys
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bread always falls buttered side down
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dit kos ‘n plaas se geld
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# praat is goedkoop omdat die aanbod die aanvraag vér oorskry
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# “sy skop nie baie watts uit nie”  – ingestuur deur hanlie
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# uit het oog uit het hart
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cool as a cucumber
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# “pasop vir chantel sy brand die kookwater”
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# horse a horse my kingdom for a horse  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go by the board
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# face that launched a thousand ships  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# bobbejaanstuipe kry
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as fine as frogs hair
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# shut your cakehole
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# rumpypumpy
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# it never rains but it pours
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy is met sy broek op sy enkels betrap
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# belt up
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# as is en was nou nie daar was of was het is gebly en daar was nooit ‘n by wat was dan was was mos is gewees
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# jump the shark
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# nie ‘n a van ‘n b ken nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# like the clappers
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# adam sê dis eva en eva sê dis die slang
#
#
# Prediction: Nederlands
# Actual Language: Afrikaans
# Input Sentence:
# geen spiesen maacht so diepe wonden als achterklap en boose monden
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# never give a sucker an even break
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# schijn bedriegt
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# maer bokke dip
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bullet  bit the bite the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as bald as a coot
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# quicker than lager turns to piss
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hanged drawn and quartered
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a leopard cannot change its spots
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# vriende is soos bottels medisyne jy moet hulle eers goed skud voordat jy drink
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# geef hem een vinger en hij neemt de hele hand
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# vir g’n geld of goeie woorde te kry nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# toe jors sy eks sien by die kroegtoonbank spring hy knipmesom
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# take the upper hand
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ring down the curtain
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# upside down
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pony and trap
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# to the manner born
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# waar die boer nie is nie word sy baard nie geskeer nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy is al sy alies kwyt
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# four corners of the earth
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# toe ek begin werk het wou ek ‘n groot klomp geld gou maak later wou ek’n groot klomp geld maak terwyl ek dit geniet maar later sien ek wat jy werklik wil hê is om ‘n klein verskil te maak as jy dit kan doen kom ander dinge vanself en kan jy dit terdeë geniet
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# happy clappy
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# send packing
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hou op sit op my hakke
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# minced oaths
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# theres no such thing as a free lunch tanstaafl
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# on carey street
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# chip on your shoulder
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pretty kettle of fish
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# wet behind the ears
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# julius se gesante en trawante raak al minder
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die grootste diens wat aan enige land  bewys kan word is om ‘n nuttige plant tot sy landboukultuur toe te voeg
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# dance attendance on
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# basket case
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# booby prize
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# neither a borrower nor a lender be
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# high and mighty
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# upsadaisy
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# as petrol en vuur bymekaar kom brand dit en as mis en donderweer bymekaar kom reën dit
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# vir geen geld ter wêreld nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# picture is worth a thousand words  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# devil to pay  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# for every thing there is a season
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# à la carte
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in the nick of time
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fall on your sword
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# as jy wil leef op hoop alleen sal jy sterf van honger armoede en ellende
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# keep the ball rolling
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hot on the heels
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# for ever and a day
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the opera aint over till the fat lady sings
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a house divided against itself cannot stand
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# on a hiding to nothing
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# zien is geloven
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# halcyon days
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# clog up
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# keep up with the joneses
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# twenty three skidoo
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fie foh fum i smell the blood of an englishman
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# skaars uit die dop wees
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die geld brand in sy sak
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# ladida
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in trouble
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# know which way the wind blows
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# aan skuld betaal kom ‘n end maar aan spyt kom nooit ‘n end nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# show your mettle
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# beef and reef
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# san fairy ann
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bald as a coot
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy skil sy aartappels nie twee keer oor nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy het die druiwekar gery
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# my old china
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# grind to a halt
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n gat in die dag slaap
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n swak tou moet liggies getrek word
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# toecurling
#
#
# Prediction: Nederlands
# Actual Language: English
# Input Sentence:
# less is more
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# beg the question
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# god rot them
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# high and dry
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# latin phrases
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# join the colours
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# five oclock shadow
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# on a wing and a prayer
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die lewe is   wat met ons gebeur en   ons reaksie daarop
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# top notch
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy besit geen duit nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# pdq  pretty damn quick
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# before you can say jack robinson
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a foot in the door
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a little of what you fancy does you good
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# plague on both your houses  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# more light
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# let a thousand flowers bloom
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# music has charms to soothe the savage breast
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# take potluck
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy het hier aangewaai gekom
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# crackpot
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# parting shot  parthian shot
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# head over heels
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# blow your own trumpet
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die perd wat die hawer verdien kry dit nie altyd nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sy hou van haar stembande om my ore rek
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# route one
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy is ‘n regte cheapskate
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# excuse my french
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# no quarter given
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# sight for sore eyes a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# like a moth to a flame
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go out on a limb
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# so bang soos ‘n bok vir ‘n skoot hael
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the toast of the town
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# so eet dat ‘n kat nie met jou maag kan wegloop nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ryk gesaai bankrot geoes
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bread of life  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# red in tooth and claw
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fifteen minutes of fame
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# act of god
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die son sit manshoogte van die berg af
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tuckered out
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# twee vliegen in één klap slaan
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# keep a wide berth
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# riffraff
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# win one for the gipper
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# live long and prosper
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# “help vir henna en troos vir koos”
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# gierigheid is die wortel van alle kwaad
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bale outbail out
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# great unwashed  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# meet your waterloo
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# it came like a bolt from the blue
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# guts for garters
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# blaze a trail
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the mutts nuts
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the full monty
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# dis makliker om weg te bly van die aas af as om los te kom van die hoek
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die lewe het my leer dink maar die dink het my nie leer leef nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# scuse me while i kiss this guy
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ek probeer my skandelike verlede troos met goeie voornemens vir die toekoms maar hy skud net sy kop
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# which is which
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# full monty  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# mense wat min weet praat baie mense wat baie weet praat min
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a place for everything and everything in its place
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# fast asleep
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# play by ear
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# absence makes the heart grow fonder
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# plugged nickel
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# have no truck with
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# finagles law
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# punch above ones weight
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# friend in need is a friend indeed  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# joined at the hip
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# hoitytoity
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# to cast the first stone
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# trouble and strife
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# we few we happy few we band of brothers
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# knock on wood
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# beter laat dan nooit
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# double dutch
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# look before you leap
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# cordon bleu
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# i bear a charmed life
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# moenie die boot skommel nie
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# nosy parker
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die kar draai sommer hier rûens in die pad  ‘n sêding in riversdal
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die doodskleed het geen sakke nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n man se geld kan opraak solank jou planne nie opraak nie
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# geld wat geel is maak reg wat skeel is
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in your face
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# maak jou vriendelikheid goedkoop en hou jou vriendskap duur
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# onder iemand se duiwe skiet
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# “byt jy weer borrels”  – ingestuur deur lödveteig nan
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n man van twaalf ambagte en dertien ongelukke
#
#
# Prediction: Nederlands
# Actual Language: English
# Input Sentence:
# veg out
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# drop in the bucket  a
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# johann nell “dit is baie beter om te huil in ‘n luukse bmw as op ‘n tweewielfiets en dit is nog beter om jou trane te laat val van ‘n drieverdieping mansion as wat dit op jou kaia se grondvloer val”
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# as alike as two peas in a pod
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# beck and call
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# sound out
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# every cloud has a silver lining
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# genius is one percent inspiration and  percent perspiration
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# sê groete aan die vrate
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# shiver my timbers
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a fools paradise
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# spellingbee
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a turn up for the books
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# vra my broer jack hy lieg nes ek
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bad books
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# apple of my eye  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bone dry
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# broke  if it aint dont fix it
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in the limelight
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy is dopsak
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# mal jan onder die afkophoenders
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# die berg het n muis gebaar
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# three score and ten
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# diehard
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# van die gramadoelas kom
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# tie the knot
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# lark about
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# japie my skapie jy hou my hart se punt in die holte van jou skaapwagtershande
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# make my day
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy is in hart en niere ‘n bokondersteuner
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# gordon bennett
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# butt end of the stick  the
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ek sal kan doen met ‘n miljoen
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# help jou buurman om sy las te dra en jy sal jou verwonder hoveel ligter jou eie word
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# horse and cart
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# diamond is forever  a
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# praying at the porcelain altar
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# flat out
#
#
# Prediction: Afrikaans
# Actual Language: English
# Input Sentence:
# got my mojo working
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# hy gaan met aasdieromslagtigheid te werk
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# grasp the nettle
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# female of the species is more deadly then the male  the
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# the course of true love never did run smooth
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# main chance
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# eerlijkheid duurt het langst
#
#
# Prediction: Nederlands
# Actual Language: Nederlands
# Input Sentence:
# tijd vliegt
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ek sê nooit vir my werksmense – loop en gaan doen ‘n werk nie ek sê “kom ons gaan doen ‘n werk bring julle toerusting”
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# titfer
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# bottle out
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# comes to the crunch  when it
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ‘n totale ballsup van iets maak
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# you look as if youve been dragged through a hedge backwards
#
#
# Prediction: Nederlands
# Actual Language: English
# Input Sentence:
# achilles heel
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# booze cruise
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# rabbit and pork
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# a diamond in the rough
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# mutton dressed as lamb
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# annus horribilis
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# whats not to like
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go pound sand
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# power corrupts absolute power corrupts absolutely
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# sacred cow
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# rag tag and bobtail
#
#
# Prediction: Afrikaans
# Actual Language: Afrikaans
# Input Sentence:
# ŉ man saai nie koring in ŉ varkhok nie
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# go postal
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# in a pickle
